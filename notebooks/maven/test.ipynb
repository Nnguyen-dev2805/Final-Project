# %%
from pathlib import Path
import warnings
import sys
import subprocess

import numpy as np
import pandas as pd
from IPython.display import Markdown, display
import matplotlib.pyplot as plt
import seaborn as sns

try:
    from scipy import stats
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "scipy"])
    from scipy import stats

sns.set_theme(style="whitegrid")
warnings.filterwarnings("ignore", category=FutureWarning)
pd.set_option("display.max_columns", 120)
pd.set_option("display.max_rows", 100)
pd.set_option("display.float_format", lambda x: f"{x:,.4f}")

# %%
DATA_PATH = Path("../../data/Maven Market Datasets/processed/maven.csv")
df = pd.read_csv(DATA_PATH)
display(df.head())
# Out:
#          date  store_id  gross_revenue  gross_cost  gross_profit  \
# 0  1997-01-01         6       659.4300    268.6800      390.7500
# 1  1997-01-01        14        46.9100     19.5000       27.4100
# 2  1997-01-02        11       882.9400    347.2400      535.7000
# 3  1997-01-02        23       421.5900    173.9200      247.6700
# 4  1997-01-03         7       867.6400    354.0800      513.5600
#
#    quantity_sold  line_item_count  distinct_products_sold  \
# 0            324               99                      99
# 1             24               18                      18
# 2            431              140                     135
# 3            204               66                      64
# 4            394              128                     124
#
#    distinct_brands_sold  distinct_customers  avg_customer_age  \
# 0                    49                  22           51.4635
# 1                    15                   4           30.7779
# 2                    61                  32           50.1729
# 3                    41                  14           55.5141
# 4                    58                  30           54.5590
#
#    avg_unit_retail_price  avg_margin_pct_line  mean_stock_lag_days  \
# 0                 1.9911               0.5918               4.0606
# 1                 2.0083               0.5904               4.0556
# 2                 2.0661               0.6080               3.7429
# 3                 2.0321               0.5869               3.9545
# 4                 2.1860               0.5953               3.7578
#
#    return_quantity  return_value  return_cost  returned_product_count  \
# 0           3.0000        6.1100       2.2600                  3.0000
# 1           0.0000        0.0000       0.0000                  0.0000
# 2           3.0000        5.6400       2.2500                  3.0000
# 3           3.0000       10.2100       3.5700                  2.0000
# 4           5.0000       15.2600       5.6000                  4.0000
#
#    region_id           store_type store_name     store_city store_state  \
# 0         47  Gourmet Supermarket    Store 6  Beverly Hills          CA
# 1          1        Small Grocery   Store 14  San Francisco          CA
# 2         22          Supermarket   Store 11       Portland          OR
# 3         89     Mid-Size Grocery   Store 23         Yakima          WA
# 4          3          Supermarket    Store 7    Los Angeles          CA
#
#   store_country sales_district  sales_region  total_sqft  grocery_sqft  \
# 0           USA    Los Angeles    South West       23688         15337
# 1           USA  San Francisco  Central West       22478         15321
# 2           USA       Portland    North West       20319         16232
# 3           USA         Yakima    North West       29182         19283
# 4           USA    Los Angeles    South West       23598         14210
#
#   first_opened_date last_remodel_date  net_revenue weather_location_id  \
# 0        1981-01-03        1991-03-13     653.3200       maven_store_6
# 1        1957-11-24        1958-01-07      46.9100      maven_store_14
# 2        1976-09-17        1982-05-15     877.3000      maven_store_11
# 3        1977-07-16        1987-07-24     411.3800      maven_store_23
# 4        1971-05-21        1981-10-20     852.3800       maven_store_7
#
#        location_name weather_spatial_level  weather_code  temperature_max_c  \
# 0  Beverly Hills, CA            store_city            51            18.4000
# 1  San Francisco, CA            store_city            63            16.3000
# 2       Portland, OR            store_city            61            10.6000
# 3         Yakima, WA            store_city            51             6.0000
# 4    Los Angeles, CA            store_city            55            18.7000
#
#    temperature_min_c  temperature_mean_c  apparent_temperature_mean_c  \
# 0            11.9000             14.9000                      15.2000
# 1            14.9000             15.5000                      13.9000
# 2             6.6000              9.2000                       6.3000
# 3             1.5000              3.8000                       0.3000
# 4             9.8000             15.0000                      14.9000
#
#    precipitation_mm  rain_mm  snowfall_cm  wind_speed_max_kmh  \
# 0            0.1000   0.1000       0.0000              7.9000
# 1           48.1000  48.1000       0.0000             34.6000
# 2           19.3000  19.3000       0.0000             21.7000
# 3            0.1000   0.1000       0.0000             16.9000
# 4            4.1000   4.1000       0.0000              9.8000
#
#    wind_gusts_max_kmh  shortwave_radiation_mj_m2  latitude_requested  \
# 0             11.9000                     4.1400             34.0736
# 1             78.5000                     0.5700             37.7749
# 2             57.6000                     2.8900             45.5152
# 3             35.6000                     5.6400             46.6021
# 4             24.5000                     8.5400             34.0522
#
#    longitude_requested  latitude_open_meteo  longitude_open_meteo  \
# 0            -118.4004              34.0598             -118.3500
# 1            -122.4194              37.7856             -122.4096
# 2            -122.6784              45.5185             -122.6374
# 3            -120.5059              46.5729             -120.5306
# 4            -118.2437              34.0598             -118.2375
#
#    elevation_m             timezone  utc_offset_seconds      weather_source
# 0      83.0000  America/Los_Angeles              -25200  open_meteo_archive
# 1      18.0000  America/Los_Angeles              -25200  open_meteo_archive
# 2      25.0000  America/Los_Angeles              -25200  open_meteo_archive
# 3     325.0000  America/Los_Angeles              -25200  open_meteo_archive
# 4      91.0000  America/Los_Angeles              -25200  open_meteo_archive

# %%
df.shape
# Out:
# (1560, 53)
